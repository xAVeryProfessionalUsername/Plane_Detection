# %%
import os
import arcpy

# %%
directory = r"C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2"

# List all files in the directory
files = os.listdir(directory)

# Loop through the files and rename them
for index, filename in enumerate(files):
    # Construct the old file path
    old_file = os.path.join(directory, filename)
    
    # Create the new filename with an index
    new_filename = str(index + 1) + '.jpg'
    
    # Construct the new file path
    new_file = os.path.join(directory, new_filename)
    
    # Rename the file
    os.rename(old_file, new_file)

# %%
aprx_path = r'C:\Users\nicks\OneDrive\Documents\ArcGIS\Projects\planedetectioncivvie\planedetectioncivvie.aprx'

aprx = arcpy.mp.ArcGISProject(aprx_path)

for num in range(1,65):
    mapname = 'Map' + str(num)
    print(mapname)
    map = aprx.listMaps(mapname)[0]
    

    layer = r"C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2" + '\\' + str(num) + '.jpg'
    
    print(layer)
    map.addDataFromPath(layer)
# Out:
# Map1
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\1.jpg
# Map2
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\2.jpg
# Map3
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\3.jpg
# Map4
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\4.jpg
# Map5
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\5.jpg
# Map6
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\6.jpg
# Map7
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\7.jpg
# Map8
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\8.jpg
# Map9
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\9.jpg
# Map10
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\10.jpg
# Map11
# C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\images2\11.jpg
# Map12
# ...

# %%
import os
import arcpy
# from arcpy import env
arcpy.CheckOutExtension("ImageAnalyst")
from arcpy.ia import *

# %%
directory = r"C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\masks"

# List all files in the directory
files = os.listdir(directory)

# Loop through the files and rename them
for index, filename in enumerate(files):
    # Construct the old file path
    old_file = os.path.join(directory, filename)
    
    # Create the new filename with an index
    new_filename = filename.replace('layer', 'label')
    
    # Construct the new file path
    new_file = os.path.join(directory, new_filename)
    
    # Rename the file
    os.rename(old_file, new_file)

# %%
import os
import os
import arcpy
# from arcpy import env
arcpy.CheckOutExtension("ImageAnalyst")
from arcpy.ia import *


arcpy.env.workspace = r"C:\Users\nicks\OneDrive\Documents\ArcGIS\Projects\MyProject19\MyProject19.gdb"
arcpy.env.overwriteOutput

aprx = arcpy.mp.ArcGISProject(r"C:\Users\nicks\OneDrive\Documents\ArcGIS\Projects\MyProject19\MyProject19.aprx")

def extract_number_from_string(s):
    match = re.search(r'\d+', s)
    return int(match.group()) if match else None

directory = r"C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\masks_modified" 
imagespath = r"C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\imagesformodified"
chippath = r"C:\Users\nicks\OneDrive\Desktop\VSprojects\Betterplanedetection\chips"

files = os.listdir(directory)
imagefiles = os.listdir(imagespath)

print(imagefiles)
num = 0
for index, filename in enumerate(files):
    
    if filename.endswith('.shp'):
    
        
        number = extract_number_from_string(filename)
        imagefile = str(number) + '.jpg'
        print(filename)
        print(imagefile)


        arcpy.ia.ExportTrainingDataForDeepLearning(
        in_raster= os.path.join(imagespath,imagefile),
        out_folder= chippath + '\\' + str(num),
        in_class_data= os.path.join(directory, filename),
        image_chip_format="JPEG",
        tile_size_x=1024,
        tile_size_y=1024,
        stride_x=512,
        stride_y=512,
        output_nofeature_tiles="ALL_TILES",
        metadata_format="RCNN_Masks",
        start_index=0,
        class_value_field=None,
        buffer_radius=0,
        in_mask_polygons=None,
        rotation_angle=0,
        reference_system="MAP_SPACE",
        processing_mode="PROCESS_AS_MOSAICKED_IMAGE",
        blacken_around_feature="NO_BLACKEN",
        crop_mode="FIXED_SIZE",
        in_raster2=None,
        in_instance_data=None,
        instance_class_value_field=None,
        min_polygon_overlap_ratio=0
    )
        num +=1
# Out:
# ['1.jpg', '10.jpg', '11.jpg', '12.jpg', '13.jpg', '14.jpg', '15.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg', '2.jpg', '20.jpg', '21.jpg', '22.jpg', '23.jpg', '24.jpg', '25.jpg', '26.jpg', '27.jpg', '28.jpg', '29.jpg', '3.jpg', '30.jpg', '31.jpg', '32.jpg', '33.jpg', '34.jpg', '35.jpg', '36.jpg', '37.jpg', '38.jpg', '39.jpg', '4.jpg', '40.jpg', '41.jpg', '49.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']
# label10modified.shp
# 10.jpg
# label11modified.shp
# 11.jpg
# label12modified.shp
# 12.jpg
# label13modified.shp
# 13.jpg
# label14modified.shp
# 14.jpg
# label15modified.shp
# 15.jpg
# label16modified.shp
# 16.jpg
# label17modified.shp
# 17.jpg
# label18modified.shp
# 18.jpg
# label19modified.shp
# 19.jpg
# label1modified.shp
# 1.jpg
# label20modified.shp
# 20.jpg
# label21modified.shp
# 21.jpg
# label22modified.shp
# 22.jpg
# label23modified.shp
# 23.jpg
# label24modified.shp
# 24.jpg
# label25modified.shp
# 25.jpg
# label26modified.shp
# 26.jpg
# label27modified.shp
# ...
